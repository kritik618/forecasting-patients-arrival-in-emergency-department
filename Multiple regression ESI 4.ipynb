# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import holidays
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_excel(r"C:\Users\kriti\kriti python\Hourly Patient Data.xlsx")

# %%
data['Time'] = pd.to_datetime(data['Time'])

# %%
data.set_index('Time', inplace=True)

# %%
data.drop(columns=['ESI 1', 'ESI 2', 'ESI 3', 'ESI 5'], inplace=True)

# %%
esi1_daily = data['ESI 4'].resample('D').sum()

# %%
esi1_daily_df = esi1_daily.reset_index()

# %%
esi1_daily_df.columns = ['Date', 'ESI 4']

# %%
print(esi1_daily_df)
# Out:
#            Date  ESI 4
# 0    2017-01-01     47
# 1    2017-01-02     66
# 2    2017-01-03     51
# 3    2017-01-04     41
# 4    2017-01-05     46
# ...         ...    ...
# 1456 2020-12-27     36
# 1457 2020-12-28     40
# 1458 2020-12-29     51
# 1459 2020-12-30     38
# 1460 2020-12-31     37
#
# [1461 rows x 2 columns]

# %%
train = esi1_daily_df.iloc[:int(len(esi1_daily_df)*0.9)]
test = esi1_daily_df.iloc[int(len(esi1_daily_df)*0.9):]

# %%
us_holidays = holidays.US(years=range(2017, 2021))

# %%
train['Date'] = pd.to_datetime(train['Date'])
train['Holiday'] = train['Date'].apply(lambda x: int(x in us_holidays))
train['Day_of_Week'] = train['Date'].dt.day_name()
train['Month'] = train['Date'].dt.month
train['Trend'] = range(1, len(train) + 1)
# Out:
# C:\Users\kriti\AppData\Local\Temp\ipykernel_23996\2476409844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Date'] = pd.to_datetime(train['Date'])
# C:\Users\kriti\AppData\Local\Temp\ipykernel_23996\2476409844.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Holiday'] = train['Date'].apply(lambda x: int(x in us_holidays))
# C:\Users\kriti\AppData\Local\Temp\ipykernel_23996\2476409844.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Day_of_Week'] = train['Date'].dt.day_name()
# C:\Users\kriti\AppData\Local\Temp\ipykernel_23996\2476409844.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Month'] = train['Date'].dt.month
# C:\Users\kriti\AppData\Local\Temp\ipykernel_23996\2476409844.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Trend'] = range(1, len(train) + 1)

# %%
train.rename(columns={'ESI 4': 'ESI_4'}, inplace=True)

e
res = smf.ols(formula='ESI_4 ~ C(Holiday) + C(Day_of_Week) + C(Month) + Trend + I(Trend**2) + I(Trend**3)', data=train).fit()
# Out:
# C:\Users\kriti\AppData\Local\Temp\ipykernel_23996\3427962953.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.rename(columns={'ESI 4': 'ESI_4'}, inplace=True)

# %%
test['Date'] = pd.to_datetime(test['Date'])
test['Holiday'] = test['Date'].apply(lambda x: int(x in us_holidays))
test['Day_of_Week'] = test['Date'].dt.day_name()
test['Month'] = test['Date'].dt.month
test['Trend'] = range(len(train) + 1, len(train) + len(test) + 1)
# Out:
# C:\Users\kriti\AppData\Local\Temp\ipykernel_23996\2015112868.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Date'] = pd.to_datetime(test['Date'])
# C:\Users\kriti\AppData\Local\Temp\ipykernel_23996\2015112868.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Holiday'] = test['Date'].apply(lambda x: int(x in us_holidays))
# C:\Users\kriti\AppData\Local\Temp\ipykernel_23996\2015112868.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Day_of_Week'] = test['Date'].dt.day_name()
# C:\Users\kriti\AppData\Local\Temp\ipykernel_23996\2015112868.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Month'] = test['Date'].dt.month
# C:\Users\kriti\AppData\Local\Temp\ipykernel_23996\2015112868.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Trend'] = range(len(train) + 1, len(train) + len(test) + 1)

# %%
ypred = res.predict(test)

# %%
# Check the column names in train and test data
print(train.columns)
# Out:
# Index(['Date', 'ESI_4', 'Holiday', 'Day_of_Week', 'Month', 'Trend'], dtype='object')

# %%
# Check the column names in train and test data

print(test.columns)
# Out:
# Index(['Date', 'ESI 4', 'Holiday', 'Day_of_Week', 'Month', 'Trend'], dtype='object')

# %%
plt.figure(figsize=(12, 6))
plt.plot(train['Date'], train['ESI_4'], label='Training Data')
plt.plot(test['Date'], test['ESI 4'], label='Test Data (Actual)', linestyle='--')
plt.plot(test['Date'], ypred, label='Test Data (Forecast)', linestyle='--')
plt.xlabel('Date')
plt.ylabel('ESI_4')
plt.title('Actual Data Before and After Forecast')
plt.legend()
plt.show()

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mape = mean_absolute_percentage_error(test['ESI 4'], ypred)
print("MAPE:", mape)
# Out:
# MAPE: 16.287597848268323

# %%
rmse = np.sqrt(mean_squared_error(test['ESI 4'], ypred))
print("RMSE:", rmse)
# Out:
# RMSE: 7.024896058217581

# %%
import numpy as np

def mean_absolute_error(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))



mae = mean_absolute_error(test['ESI 4'], ypred)
print("MAE:", mae)
# Out:
# MAE: 5.597648152792308
